# %% [markdown]
# # Accessible Scatterplots in R
#
# This notebook is a standalone teaching resource for creating accessible scatterplots with **ggplot2** in R.

# %% [markdown]
# ## What this graph is used for
#
# Scatterplots are used to represent relationships between two variables and to reveal correlation or clustering patterns.
#
# ## How to make it more accessible
#
# Clearly identify what each axis represents, use meaningful contextual labels, increase marker size, provide a descriptive title, and use grid lines where they support reading values. Use high-contrast markers and do not depend on color alone.

# %% [markdown]
# ## Setup
#
# This notebook uses **ggplot2**, the plotting library used throughout the supplied R teaching materials.
#
# If `ggplot2` is not installed in your R environment, install it once with:
#
# ```r
# install.packages("ggplot2")
# ```
#
# Then load it with `library(ggplot2)`.
#
# The Python notebooks use MatplotAlt to generate four levels of alternative-text description automatically. MatplotAlt is Python-specific, so the R notebooks keep the same teaching structure but provide the four description levels as Markdown text. For the reusable template, a four-level description template is provided for you to adapt to your own data.

# %%
library(ggplot2)

# %% [markdown]
# ## Accessible example
#
# The code below showcases an accessibility-aware example of a scatterplot created in R.

# %%
study_hours <- c(1, 2, 3, 4, 5)
exam_scores <- c(50, 60, 72, 85, 95)

scatter_data <- data.frame(
  study_hours = study_hours,
  exam_scores = exam_scores
)

ggplot(scatter_data, aes(x = study_hours, y = exam_scores)) +
  geom_point(
    color = "black",
    shape = 16,
    size = 4
  ) +
  labs(
    title = "Relationship Between Study Time and Exam Performance",
    x = "Study Time (Hours)",
    y = "Exam Score (%)"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(size = 16),
    panel.grid.minor = element_blank()
  )
# Out:
# plot without title

# %% [markdown]
# ## Reusable accessible template
#
# Replace the placeholder values and labels with your own data while retaining clear labels, a descriptive title, large high-contrast markers, and an uncluttered grid.

# %%
# Replace the placeholder data and text below with your own values.
x_values <- c(1, 2, 3, 4, 5)
y_values <- c(12, 18, 21, 29, 34)

x_axis_label <- "First variable (unit)"
y_axis_label <- "Second variable (unit)"
graph_title <- "Descriptive title explaining the relationship"

template_data <- data.frame(
  x = x_values,
  y = y_values
)

ggplot(template_data, aes(x = x, y = y)) +
  geom_point(
    color = "black",
    shape = 16,
    size = 4
  ) +
  labs(
    title = graph_title,
    x = x_axis_label,
    y = y_axis_label
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(size = 16),
    panel.grid.minor = element_blank()
  )

# %% [markdown]
# ### Four-level description template for your graph
#
# After replacing the placeholder data, update the descriptions below so that they match the graph you generated.
#
# **Level 1 — chart structure and encodings**
#
# State the chart type, title, axes or categories, units, and the visual encodings used.
#
# **Level 2 — data/statistical detail**
#
# Summarize important values, ranges, minima/maxima, counts, quartiles, or other relevant statistics.
#
# **Level 3 — trends or relationships**
#
# Describe the main trend, association, distribution pattern, clustering, or comparison shown by the graph.
#
# **Level 4 — broader interpretation**
#
# Explain the main contextual takeaway of the graph without adding claims that are not supported by the plotted data.
